# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("../src/")

import irf_function
from irf_function import IRF

# %%
# %matplotlib inline
irf = IRF(path="../data/simulation-requirements/wavelengths_mu.csv")
irf.plot_irf()
